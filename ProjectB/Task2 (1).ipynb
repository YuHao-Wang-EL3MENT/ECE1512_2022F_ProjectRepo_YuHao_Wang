# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ECE1512/ProjectB/Matching_Traj/mtt-distillation-main
# Out:
# /content/drive/MyDrive/ECE1512/ProjectB/Matching_Traj/mtt-distillation-main

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ECE1512/ProjectB/Matching_Traj/mtt-distillation-main

# %%
# !pip install kornia

# %%
# !python buffer.py \
    --dataset 'CIFAR10' \
    --model 'ConvNet' \
    --num_experts 100 \
    --train_epochs 50 \
    --zca \
    --buffer_path '/content/drive/MyDrive/ECE1512/ProjectB/Matching_Traj/mtt-distillation-main/buffers'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train ZCA
# 100% 50000/50000 [00:05<00:00, 9040.50it/s]
# Test ZCA
# 100% 10000/10000 [00:00<00:00, 10099.54it/s]
# Hyper-parameters:
#  {'dataset': 'CIFAR10', 'subset': 'imagenette', 'model': 'ConvNet', 'num_experts': 100, 'lr_teacher': 0.01, 'batch_train': 256, 'batch_real': 256, 'dsa': True, 'dsa_strategy': 'color_crop_cutout_flip_scale_rotate', 'data_path': 'data', 'buffer_path': '/content/drive/MyDrive/ECE1512/ProjectB/Matching_Traj/mtt-distillation-main/buffers', 'train_epochs': 50, 'zca': True, 'decay': False, 'mom': 0, 'l2': 0, 'save_interval': 10, 'device': 'cuda', 'dsa_param': <utils.ParamDiffAug object at 0x7fdea5bcc3d0>, 'zca_trans': ZCAWhitening()}
# BUILDING DATASET
# ...

# %%
# !pip install wandb

# %%
# !python distill.py \
    --dataset 'CIFAR10' \
    --ipc 10 \
    --syn_steps 20 \
    --expert_epochs 3 \
    --num_eval 1 \
    --eval_it 1000 \
    --max_start_epoch 20 \
    --zca \
    --Iteration 4000 \
    --lr_img 1000 \
    --lr_lr 1e-05 \
    --lr_teacher 0.01 \
    --pix_init 'real' \
    --buffer_path '/content/drive/MyDrive/ECE1512/ProjectB/Matching_Traj/mtt-distillation-main/buffers'
# Out:
# CUDNN STATUS: True
# Files already downloaded and verified
# Files already downloaded and verified
# Train ZCA
# 100% 50000/50000 [00:05<00:00, 8702.44it/s]
# Test ZCA
# 100% 10000/10000 [00:01<00:00, 9566.48it/s]
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.13.6
# wandb: Run data is saved locally in /content/drive/MyDrive/ECE1512/ProjectB/Matching_Traj/mtt-distillation-main/wandb/run-20221210_162607-uem5jeej
# ...

# %%
# !python distill.py \
    --dataset 'CIFAR10' \
    --ipc 10 \
    --syn_steps 20 \
    --expert_epochs 3 \
    --max_start_epoch 20 \
    --zca \
    --Iteration 1000 \
    --lr_img 1000 \
    --lr_lr 1e-05 \
    --lr_teacher 0.01 \
    --pix_init 'real' \
    --buffer_path '/content/drive/MyDrive/ECE1512/ProjectB/Matching_Traj/mtt-distillation-main/buffers/10iter_realimg'
# Out:
# CUDNN STATUS: True
# Files already downloaded and verified
# Files already downloaded and verified
# Train ZCA
# 100% 50000/50000 [00:05<00:00, 8950.36it/s]
# Test ZCA
# 100% 10000/10000 [00:01<00:00, 9911.14it/s]
# wandb: Currently logged in as: bill-wang0411 (uoft-wang). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.6
# wandb: Run data is saved locally in /content/drive/MyDrive/ECE1512/ProjectB/Matching_Traj/mtt-distillation-main/wandb/run-20221209_181746-2343erry
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run crimson-yogurt-10
# wandb: ⭐️ View project at https://wandb.ai/uoft-wang/DatasetDistillation
# wandb: 🚀 View run at https://wandb.ai/uoft-wang/DatasetDistillation/runs/2343erry
# Hyper-parameters:
# ...
